# %%
# %pylab inline
#from IPython.display import display
from PIL import Image
from io import BytesIO
import requests
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from dask.distributed import Client, progress, as_completed
client = Client()
client
# Out:
# <Client: scheduler='tcp://172.19.0.4:8786' processes=1 cores=4>

# %%
url = "https://picsum.photos/200/200/?random"

def download(i):
    i = BytesIO(requests.get("https://picsum.photos/100/100/?random").content)
    return i

futures = client.map(download, [0,1,2,3,4])
out = []
out.clear
for future, result in as_completed(futures, with_results=True):
    print("---")
    out.append(result)
# Out:
# ---
# ---
# ---
# ---
# ---

# %%
i = Image.open(out[0])
type(0)
imshow(Image.open(out[0]))
